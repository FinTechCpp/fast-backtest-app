# %% [markdown]
# # AlphaVantage API Notebook

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
global API_KEY
API_KEY = '6CC8ONFZ2RRNLNFT'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from alpha_vantage.timeseries import TimeSeries
#       2 from alpha_vantage.techindicators import TechIndicators
#       3 global API_KEY
#
# ModuleNotFoundError: No module named 'alpha_vantage'

# %%
ts = TimeSeries(key=API_KEY, output_format='pandas', indexing_type='date')
ti = TechIndicators(key=API_KEY)
# Get json object with the 30-min interval intraday data and another with  the call's metadata for January, 2005.
data, meta_data = ts.get_intraday('NDX', month='2005-01', interval='10secs')
