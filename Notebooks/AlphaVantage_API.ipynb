# %% [markdown]
# # AlphaVantage API Notebook

# %%
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.techindicators import TechIndicators
import pandas as pd
global API_KEY
API_KEY = '6CC8ONFZ2RRNLNFT'

# %%
ts = TimeSeries(key=API_KEY, output_format='pandas', indexing_type='date')
ti = TechIndicators(key=API_KEY)
# Get json object with the 30-min interval intraday data and another with  the call's metadata for January, 2005.
data, meta_data = ts.get_intraday(symbol='AAPL', month='2005-01', interval='10secs', extended_hours=True, outputsize='full')

# %%
df = pd.DataFrame(data)
print(df.shape)
#df.head()
display(df.tail())
# Out:
# (10301, 5)
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2005-01-03 08:07:00   0.9811   0.9811  0.9810    0.9810    50400.0
# 2005-01-03 08:04:00   0.9802   0.9825  0.9802    0.9825   161504.0
# 2005-01-03 08:03:00   0.9795   0.9796  0.9795    0.9796    16800.0
# 2005-01-03 08:02:00   0.9704   0.9704  0.9704    0.9704   304360.0
# 2005-01-03 08:00:00   0.9780   0.9784  0.9780    0.9784    33488.0

# %%
import requests
import json
import pandas as pd

# replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
url = 'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=qqq&apikey=6CC8ONFZ2RRNLNFT'
r = requests.get(url)
data = r.json()

# Pretty print the JSON with indentation
#print("Full JSON Response:")
#print(json.dumps(data, indent=4))

# Convert the bestMatches to a pandas DataFrame for a cleaner view
if 'bestMatches' in data:
    matches_df = pd.DataFrame(data['bestMatches'])
    print("\nMatching Symbols as DataFrame:")
    print(matches_df)
else:
    print("\nNo matches found or unexpected response format")
