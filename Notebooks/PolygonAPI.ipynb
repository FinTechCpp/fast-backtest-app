# %% [markdown]
# ## PolygonAPI

# %%
from polygon import RESTClient
client = RESTClient(api_key="v2Ys0KcpMF_7P_EdBzR7znbLbkKFvQuR")

# %%
client = RESTClient("v2Ys0KcpMF_7P_EdBzR7znbLbkKFvQuR")

aggs = []
for a in client.list_aggs(
    "I:NDX",
    1,
    "second",
    "2024-01-01",
    "2025-04-30",
    sort="asc",
    limit=50000,
):
    aggs.append(a)

print(aggs)
# Out:
# ---------------------------------------------------------------------------
# BadResponse                               Traceback (most recent call last)
# Cell In[4], line 4
#       1 client = RESTClient("v2Ys0KcpMF_7P_EdBzR7znbLbkKFvQuR")
#       3 aggs = []
# ----> 4 for a in client.list_aggs(
#       5     "I:NDX",
#       6     1,
#       7     "second",
#       8     "2024-01-01",
#       9     "2025-04-30",
#      10     sort="asc",
#      11     limit=50000,
#      12 ):
#      13     aggs.append(a)
#      15 print(aggs)
#
# File ~/miniconda3/envs/trading/lib/python3.12/site-packages/polygon/rest/base.py:211, in BaseClient._paginate_iter(self, path, params, deserializer, result_key, options)
#     202 def _paginate_iter(
#     203     self,
#     204     path: str,
#    (...)    208     options: Optional[RequestOptionBuilder] = None,
#     209 ):
#     210     while True:
# --> 211         resp = self._get(
#     212             path=path,
# ...
